# %% [markdown]
# # train

# %%
# train.py
import os.path as osp
from modelscope.trainers import build_trainer
from modelscope.msdatasets import MsDataset
from modelscope.utils.hub import read_config


model_id = 'damo/nlp_structbert_sentence-similarity_chinese-base'

WORK_DIR = './workspace'

cfg = read_config(model_id)
cfg.train.max_epochs = 10
cfg.train.work_dir = WORK_DIR
cfg.train.hooks = cfg.train.hooks = [{
        'type': 'TextLoggerHook',
        'interval': 100
    }]
cfg_file = osp.join(WORK_DIR, 'train_config.json')
cfg.dump(cfg_file)

local_data = MsDataset.load('csv', data_files={'train': ['./train.csv'], 'test': ['./test.csv']}) 

train_dataset = local_data['train'].to_hf_dataset()
eval_dataset = local_data['test'].to_hf_dataset()

# map float to index
def map_labels(examples):
    map_dict = {0: "不相似", 1: "相似"}
    examples['label'] = map_dict[int(examples['label'])]
    return examples

train_dataset = train_dataset.map(map_labels)
eval_dataset = eval_dataset.map(map_labels)

kwargs = dict(
    model=model_id,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    cfg_file=cfg_file)


trainer = build_trainer(name='nlp-base-trainer',default_args=kwargs)

print('===============================================================')
print('pre-trained model loaded, training started:')
print('===============================================================')

trainer.train()

print('===============================================================')
print('train success.')
print('===============================================================')

for i in range(cfg.train.max_epochs):
    eval_results = trainer.evaluate(f'{WORK_DIR}/epoch_{i+1}.pth')
    print(f'epoch {i} evaluation result:')
    print(eval_results)


print('===============================================================')
print('evaluate success')
print('===============================================================')
# Out:
# 2023-05-17 20:46:04,609 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# Using custom data configuration default-de0d0344efc1eb27
# Found cached dataset csv (/root/.cache/modelscope/hub/datasets/csv/default-de0d0344efc1eb27/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
#   0%|          | 0/2 [00:00<?, ?it/s]
# Loading cached processed dataset at /root/.cache/modelscope/hub/datasets/csv/default-de0d0344efc1eb27/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-78ac892ea7e407b2.arrow
# Loading cached processed dataset at /root/.cache/modelscope/hub/datasets/csv/default-de0d0344efc1eb27/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317/cache-de2d2f855260bd34.arrow
# 2023-05-17 20:46:06,540 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-17 20:46:07,156 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-17 20:46:07,568 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-17 20:46:07,785 - modelscope - INFO - initialize model from /mnt/workspace/.cache/modelscope/damo/nlp_structbert_sentence-similarity_chinese-base
# 2023-05-17 20:46:09,744 - modelscope - INFO - The key of sentence1: sentence1, The key of sentence2: sentence2, The key of label: label
# 2023-05-17 20:46:09,750 - modelscope - INFO - The key of sentence1: sentence1, The key of sentence2: sentence2, The key of label: label
# 2023-05-17 20:46:09,751 - modelscope - WARNING - ('CUSTOM_DATASETS', 'sentence-similarity', 'structbert') not found in ast index file
# 2023-05-17 20:46:09,752 - modelscope - WARNING - ('CUSTOM_DATASETS', 'sentence-similarity', 'structbert') not found in ast index file
# 2023-05-17 20:46:09,817 - modelscope - INFO - ==========================Training Config Start==========================
# 2023-05-17 20:46:09,819 - modelscope - INFO - {
#     "framework": "pytorch",
#     "task": "sentence-similarity",
#     "preprocessor": {
#         "train": {
#             "type": "sen-sim-tokenizer",
#             "first_sequence": "sentence1",
#             "second_sequence": "sentence2",
#             "mode": "train",
#             "use_fast": true
#         },
#         "val": {
#             "type": "sen-sim-tokenizer",
#             "first_sequence": "sentence1",
#             "second_sequence": "sentence2",
#             "mode": "eval",
#             "use_fast": true
#         }
#     },
#     "model": {
#         "type": "structbert"
#     },
#     "pipeline": {
#         "type": "sentence-similarity"
#     },
#     "train": {
#         "work_dir": "./workspace",
#         "max_epochs": 10,
#         "dataloader": {
#             "batch_size_per_gpu": 16,
#             "workers_per_gpu": 1
#         },
#         "optimizer": {
#             "type": "SGD",
#             "lr": 0.01,
#             "options": {
#                 "grad_clip": {
#                     "max_norm": 2.0
#                 }
#             }
#         },
#         "lr_scheduler": {
#             "type": "StepLR",
#             "step_size": 2,
#             "options": {
#                 "warmup": {
#                     "type": "LinearWarmup",
#                     "warmup_iters": 2
#                 }
#             }
#         },
#         "hooks": [
#             {
#                 "type": "IterTimerHook"
#             }
#         ],
#         "logging": {
#             "interval": 100
#         },
#         "checkpoint": {
#             "period": {
#                 "interval": 1
#             }
#         }
#     },
#     "evaluation": {
#         "dataloader": {
#             "batch_size_per_gpu": 16,
#             "workers_per_gpu": 1,
#             "shuffle": false
#         }
#     }
# }
# 2023-05-17 20:46:09,820 - modelscope - INFO - ===========================Training Config End===========================
# 2023-05-17 20:46:09,822 - modelscope - WARNING - ('OPTIMIZER', 'default', 'SGD') not found in ast index file
# 2023-05-17 20:46:09,824 - modelscope - WARNING - ('LR_SCHEDULER', 'default', 'StepLR') not found in ast index file
# 2023-05-17 20:46:09,826 - modelscope - INFO - Stage: before_run:
#     (ABOVE_NORMAL) OptimizerHook
#     (LOW         ) LrSchedulerHook
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: before_train_epoch:
#     (LOW         ) LrSchedulerHook
#  --------------------
# Stage: after_train_iter:
#     (ABOVE_NORMAL) OptimizerHook
#     (LOW         ) LrSchedulerHook
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_train_epoch:
#     (LOW         ) LrSchedulerHook
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_val_epoch:
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_run:
#     (LOW         ) CheckpointHook
#  --------------------
#  --- Hook strategies info ---
#
#  --- Hook strategies info end ---
# ** build_dataset error log: 'structbert is not in the custom_datasets registry group sentence-similarity. Please make sure the correct version of ModelScope library is used.'
# ** build_dataset error log: 'structbert is not in the custom_datasets registry group sentence-similarity. Please make sure the correct version of ModelScope library is used.'
# ===============================================================
# pre-trained model loaded, training started:
# ===============================================================
# 2023-05-17 20:46:09,979 - modelscope - INFO - Checkpoints will be saved to ./workspace
# 2023-05-17 20:46:09,980 - modelscope - INFO - Text logs will be saved to ./workspace
# 2023-05-17 20:46:30,510 - modelscope - INFO - epoch [1][100/5660]	lr: 1.000e-03, eta: 3:13:10, iter_time: 0.205, data_load_time: 0.016, memory: 7484, loss: 0.9874
# 2023-05-17 20:46:50,896 - modelscope - INFO - epoch [1][200/5660]	lr: 1.000e-03, eta: 3:12:13, iter_time: 0.204, data_load_time: 0.014, memory: 7484, loss: 0.5434
# 2023-05-17 20:47:11,386 - modelscope - INFO - epoch [1][300/5660]	lr: 1.000e-03, eta: 3:12:00, iter_time: 0.205, data_load_time: 0.014, memory: 7484, loss: 0.5358
# 2023-05-17 20:47:31,950 - modelscope - INFO - epoch [1][400/5660]	lr: 1.000e-03, eta: 3:11:54, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5049
# 2023-05-17 20:47:52,564 - modelscope - INFO - epoch [1][500/5660]	lr: 1.000e-03, eta: 3:11:47, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5176
# 2023-05-17 20:48:13,233 - modelscope - INFO - epoch [1][600/5660]	lr: 1.000e-03, eta: 3:11:41, iter_time: 0.207, data_load_time: 0.014, memory: 7484, loss: 0.4929
# 2023-05-17 20:48:34,118 - modelscope - INFO - epoch [1][700/5660]	lr: 1.000e-03, eta: 3:11:48, iter_time: 0.209, data_load_time: 0.016, memory: 7484, loss: 0.5202
# 2023-05-17 20:48:54,770 - modelscope - INFO - epoch [1][800/5660]	lr: 1.000e-03, eta: 3:11:32, iter_time: 0.207, data_load_time: 0.014, memory: 7484, loss: 0.4939
# 2023-05-17 20:49:15,354 - modelscope - INFO - epoch [1][900/5660]	lr: 1.000e-03, eta: 3:11:11, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5265
# 2023-05-17 20:49:35,938 - modelscope - INFO - epoch [1][1000/5660]	lr: 1.000e-03, eta: 3:10:49, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5019
# 2023-05-17 20:49:56,548 - modelscope - INFO - epoch [1][1100/5660]	lr: 1.000e-03, eta: 3:10:30, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5349
# 2023-05-17 20:50:17,154 - modelscope - INFO - epoch [1][1200/5660]	lr: 1.000e-03, eta: 3:10:09, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5249
# 2023-05-17 20:50:37,772 - modelscope - INFO - epoch [1][1300/5660]	lr: 1.000e-03, eta: 3:09:50, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5074
# 2023-05-17 20:50:58,429 - modelscope - INFO - epoch [1][1400/5660]	lr: 1.000e-03, eta: 3:09:32, iter_time: 0.207, data_load_time: 0.014, memory: 7484, loss: 0.4861
# 2023-05-17 20:51:19,034 - modelscope - INFO - epoch [1][1500/5660]	lr: 1.000e-03, eta: 3:09:11, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5024
# 2023-05-17 20:51:39,633 - modelscope - INFO - epoch [1][1600/5660]	lr: 1.000e-03, eta: 3:08:50, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4800
# 2023-05-17 20:52:00,245 - modelscope - INFO - epoch [1][1700/5660]	lr: 1.000e-03, eta: 3:08:30, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4913
# 2023-05-17 20:52:20,848 - modelscope - INFO - epoch [1][1800/5660]	lr: 1.000e-03, eta: 3:08:09, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4793
# 2023-05-17 20:52:41,446 - modelscope - INFO - epoch [1][1900/5660]	lr: 1.000e-03, eta: 3:07:49, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4855
# 2023-05-17 20:53:02,044 - modelscope - INFO - epoch [1][2000/5660]	lr: 1.000e-03, eta: 3:07:28, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4841
# 2023-05-17 20:53:22,641 - modelscope - INFO - epoch [1][2100/5660]	lr: 1.000e-03, eta: 3:07:07, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4867
# 2023-05-17 20:53:43,237 - modelscope - INFO - epoch [1][2200/5660]	lr: 1.000e-03, eta: 3:06:46, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4718
# 2023-05-17 20:54:03,855 - modelscope - INFO - epoch [1][2300/5660]	lr: 1.000e-03, eta: 3:06:26, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4739
# 2023-05-17 20:54:24,452 - modelscope - INFO - epoch [1][2400/5660]	lr: 1.000e-03, eta: 3:06:05, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.5125
# 2023-05-17 20:54:45,055 - modelscope - INFO - epoch [1][2500/5660]	lr: 1.000e-03, eta: 3:05:45, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.
37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3721
# 2023-05-17 21:44:19,144 - modelscope - INFO - epoch [3][5600/5660]	lr: 1.000e-03, eta: 2:15:16, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3664
# 2023-05-17 21:44:31,566 - modelscope - INFO - Saving checkpoint at 3 epoch
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd56e2e0e60>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#     self._shutdown_workers()
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#     if w.is_alive():
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fd56e2e0e60>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1358, in __del__
#     self._shutdown_workers()
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1341, in _shutdown_workers
#     if w.is_alive():
#   File "/opt/conda/lib/python3.7/multiprocessing/process.py", line 151, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# 2023-05-17 21:44:54,013 - modelscope - INFO - epoch [4][100/5660]	lr: 1.000e-03, eta: 2:14:17, iter_time: 0.210, data_load_time: 0.018, memory: 7484, loss: 0.3847
# 2023-05-17 21:45:14,632 - modelscope - INFO - epoch [4][200/5660]	lr: 1.000e-03, eta: 2:13:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3744
# 2023-05-17 21:45:35,252 - modelscope - INFO - epoch [4][300/5660]	lr: 1.000e-03, eta: 2:13:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3770
# 2023-05-17 21:45:55,865 - modelscope - INFO - epoch [4][400/5660]	lr: 1.000e-03, eta: 2:13:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3643
# 2023-05-17 21:46:16,475 - modelscope - INFO - epoch [4][500/5660]	lr: 1.000e-03, eta: 2:12:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3776
# 2023-05-17 21:46:37,084 - modelscope - INFO - epoch [4][600/5660]	lr: 1.000e-03, eta: 2:12:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3699
# 2023-05-17 21:46:57,692 - modelscope - INFO - epoch [4][700/5660]	lr: 1.000e-03, eta: 2:12:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3860
# 2023-05-17 21:47:18,302 - modelscope - INFO - epoch [4][800/5660]	lr: 1.000e-03, eta: 2:11:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3693
# 2023-05-17 21:47:38,910 - modelscope - INFO - epoch [4][900/5660]	lr: 1.000e-03, eta: 2:11:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3848
# 2023-05-17 21:47:59,515 - modelscope - INFO - epoch [4][1000/5660]	lr: 1.000e-03, eta: 2:11:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3796
# 2023-05-17 21:48:20,130 - modelscope - INFO - epoch [4][1100/5660]	lr: 1.000e-03, eta: 2:10:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3634
# 2023-05-17 21:48:40,738 - modelscope - INFO - epoch [4][1200/5660]	lr: 1.000e-03, eta: 2:10:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3685
# 2023-05-17 21:49:01,332 - modelscope - INFO - epoch [4][1300/5660]	lr: 1.000e-03, eta: 2:10:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3617
# 2023-05-17 21:49:21,919 - modelscope - INFO - epoch [4][1400/5660]	lr: 1.000e-03, eta: 2:09:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3729
# 2023-05-17 21:49:42,506 - modelscope - INFO - epoch [4][1500/5660]	lr: 1.000e-03, eta: 2:09:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3571
# 2023-05-17 21:50:03,105 - modelscope - INFO - epoch [4][1600/5660]	lr: 1.000e-03, eta: 2:09:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3733
# 2023-05-17 21:50:23,710 - modelscope - INFO - epoch [4][1700/5660]	lr: 1.000e-03, eta: 2:08:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3806
# 2023-05-17 21:50:44,310 - modelscope - INFO - epoch [4][1800/5660]	lr: 1.000e-03, eta: 2:08:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3708
# 2023-05-17 21:51:04,910 - modelscope - INFO - epoch [4][1900/5660]	lr: 1.000e-03, eta: 2:08:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3690
# 2023-05-17 21:51:25,513 - modelscope - INFO - epoch [4][2000/5660]	lr: 1.000e-03, eta: 2:07:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3830
# 2023-05-17 21:51:46,111 - modelscope - INFO - epoch [4][2100/5660]	lr: 1.000e-03, eta: 2:07:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3652
# 2023-05-17 21:52:06,708 - modelscope - INFO - epoch [4][2200/5660]	lr: 1.000e-03, eta: 2:07:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.
iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3607
# 2023-05-17 22:08:50,479 - modelscope - INFO - epoch [5][1400/5660]	lr: 1.000e-04, eta: 1:50:42, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3550
# 2023-05-17 22:09:11,100 - modelscope - INFO - epoch [5][1500/5660]	lr: 1.000e-04, eta: 1:50:22, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3740
# 2023-05-17 22:09:31,724 - modelscope - INFO - epoch [5][1600/5660]	lr: 1.000e-04, eta: 1:50:02, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3919
# 2023-05-17 22:09:52,358 - modelscope - INFO - epoch [5][1700/5660]	lr: 1.000e-04, eta: 1:49:42, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3709
# 2023-05-17 22:10:12,989 - modelscope - INFO - epoch [5][1800/5660]	lr: 1.000e-04, eta: 1:49:21, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3507
# 2023-05-17 22:10:33,621 - modelscope - INFO - epoch [5][1900/5660]	lr: 1.000e-04, eta: 1:49:01, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3566
# 2023-05-17 22:10:54,258 - modelscope - INFO - epoch [5][2000/5660]	lr: 1.000e-04, eta: 1:48:41, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3547
# 2023-05-17 22:11:14,878 - modelscope - INFO - epoch [5][2100/5660]	lr: 1.000e-04, eta: 1:48:21, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3707
# 2023-05-17 22:11:35,498 - modelscope - INFO - epoch [5][2200/5660]	lr: 1.000e-04, eta: 1:48:01, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3816
# 2023-05-17 22:11:56,122 - modelscope - INFO - epoch [5][2300/5660]	lr: 1.000e-04, eta: 1:47:41, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.4008
# 2023-05-17 22:12:16,746 - modelscope - INFO - epoch [5][2400/5660]	lr: 1.000e-04, eta: 1:47:21, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3631
# 2023-05-17 22:12:37,373 - modelscope - INFO - epoch [5][2500/5660]	lr: 1.000e-04, eta: 1:47:01, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3601
# 2023-05-17 22:12:57,996 - modelscope - INFO - epoch [5][2600/5660]	lr: 1.000e-04, eta: 1:46:40, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3769
# 2023-05-17 22:13:18,631 - modelscope - INFO - epoch [5][2700/5660]	lr: 1.000e-04, eta: 1:46:20, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3664
# 2023-05-17 22:13:39,261 - modelscope - INFO - epoch [5][2800/5660]	lr: 1.000e-04, eta: 1:46:00, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3683
# 2023-05-17 22:13:59,878 - modelscope - INFO - epoch [5][2900/5660]	lr: 1.000e-04, eta: 1:45:40, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3601
# 2023-05-17 22:14:20,485 - modelscope - INFO - epoch [5][3000/5660]	lr: 1.000e-04, eta: 1:45:20, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3571
# 2023-05-17 22:14:41,107 - modelscope - INFO - epoch [5][3100/5660]	lr: 1.000e-04, eta: 1:45:00, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3717
# 2023-05-17 22:15:01,719 - modelscope - INFO - epoch [5][3200/5660]	lr: 1.000e-04, eta: 1:44:39, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3668
# 2023-05-17 22:15:22,348 - modelscope - INFO - epoch [5][3300/5660]	lr: 1.000e-04, eta: 1:44:19, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3827
# 2023-05-17 22:15:43,288 - modelscope - INFO - epoch [5][3400/5660]	lr: 1.000e-04, eta: 1:43:59, iter_time: 0.209, data_load_time: 0.017, memory: 7484, loss: 0.3770
# 2023-05-17 22:16:03,913 - modelscope - INFO - epoch [5][3500/5660]	lr: 1.000e-04, eta: 1:43:39, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3454
# 2023-05-17 22:16:24,536 - modelscope - INFO - epoch [5][3600/5660]	lr: 1.000e-04, eta: 1:43:19, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3802
# 2023-05-17 22:16:45,156 - modelscope - INFO - epoch [5][3700/5660]	lr: 1.000e-04, eta: 1:42:59, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3831
# 2023-05-17 22:17:05,770 - modelscope - INFO - epoch [5][3800/5660]	lr: 1.000e-04, eta: 1:42:39, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3523
# 2023-05-17 22:17:26,400 - modelscope - INFO - epoch [5][3900/5660]	lr: 1.000e-04, eta: 1:42:19, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3358
# 2023-05-17 22:17:47,023 - modelscope - INFO - epoch [5][4000/5660]	lr: 1.000e-04, eta: 1:41:58, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3759
# 2023-05-17 22:18:07,655 - modelscope - INFO - epoch [5][4100/5660]	lr: 1.000e-04, eta: 1:41:38, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3612
# 2023-05-17 22:18:28,275 - modelscope - INFO - epoch [5][4200/5660]	lr: 1.000e-04, eta: 1:41:18, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3654
# 2023-05-17 22:18:48,901 - modelscope - INFO - epoch [5][4300/5660]	lr: 1.000e-04, eta: 1:40:58, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3752
# 2023-05-17 22:19:09,525 - modelscope - INFO - epoch [5][4400/5660]	lr: 1.000e-04, eta: 1:40:38, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3606
# 2023-05-17 22:19:30,153 - modelscope - INFO - epoch [5][4500/5660]	lr: 1.000e-04, eta: 1:40:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3749
# 2023-05-17 22:19:50,779 - modelscope - INFO - epoch [5][4600/5660]	lr: 1.000e-04, eta: 1:39:57, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3712
# 2023-05-17 22:20:11,402 - modelscope - INFO - epoch [5][4700/5660]	lr: 1.000e-04, eta: 1:39:37, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3616
# 2023-05-17 22:20:32,035 - modelscope - INFO - epoch [5][4800/5660]	lr: 1.000e-04, eta: 1:39:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3388
# 2023-05-17 22:20:52,647 - modelscope - INFO - epoch [5][4900/5660]	lr: 1.000e-04, eta: 1:38:56, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3613
# 2023-05-17 22:21:13,270 - modelscope - INFO - epoch [5][5000/5660]	lr: 1.000e-04, eta: 1:38:36, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3749
# 2023-05-17 22:21:33,895 - modelscope - INFO - epoch [5][5100/5660]	lr: 1.000e-04, eta: 1:38:16, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3535
# 2023-05-17 22:21:54,516 - modelscope - INFO - epoch [5][5200/5660]	lr: 1.000e-04, eta: 1:37:56, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3532
# 2023-05-17 22:22:15,144 - modelscope - INFO - epoch [5][5300/5660]	lr: 1.000e-04, eta: 1:37:35, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3406
# 2023-05-17 22:22:35,762 - modelscope - INFO - epoch [5][5400/5660]	lr: 1.000e-04, eta: 1:37:15, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3542
# 2023-05-17 22:22:56,387 - modelscope - INFO - epoch [5][5500/5660]	lr: 1.000e-04, eta: 1:36:55, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3752
# 2023-05-17 22:23:17,029 - modelscope - INFO - epoch [5][5600/5660]	lr: 1.000e-04, eta: 1:36:35, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3699
# 2023-05-17 22:23:29,491 - modelscope - INFO - Saving checkpoint at 5 epoch
# 2023-05-17 22:23:51,904 - modelscope - INFO - epoch [6][100/5660]	lr: 1.000e-04, eta: 1:35:50, iter_time: 0.208, data_load_time: 0.016, memory: 7484, loss: 0.3667
# 2023-05-17 22:24:12,541 - modelscope - INFO - epoch [6][200/5660]	lr: 1.000e-04, eta: 1:35:30, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3564
# 2023-05-17 22:24:33,175 - modelscope - INFO - epoch [6][300/5660]	lr: 1.000e-04, eta: 1:35:10, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.
iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3808
# 2023-05-17 22:41:03,168 - modelscope - INFO - epoch [6][5100/5660]	lr: 1.000e-04, eta: 1:18:59, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3730
# 2023-05-17 22:41:23,792 - modelscope - INFO - epoch [6][5200/5660]	lr: 1.000e-04, eta: 1:18:38, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3617
# 2023-05-17 22:41:44,410 - modelscope - INFO - epoch [6][5300/5660]	lr: 1.000e-04, eta: 1:18:18, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3753
# 2023-05-17 22:42:05,061 - modelscope - INFO - epoch [6][5400/5660]	lr: 1.000e-04, eta: 1:17:58, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3560
# 2023-05-17 22:42:25,703 - modelscope - INFO - epoch [6][5500/5660]	lr: 1.000e-04, eta: 1:17:38, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3649
# 2023-05-17 22:42:46,343 - modelscope - INFO - epoch [6][5600/5660]	lr: 1.000e-04, eta: 1:17:17, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3360
# 2023-05-17 22:42:58,792 - modelscope - INFO - Saving checkpoint at 6 epoch
# 2023-05-17 22:43:21,166 - modelscope - INFO - epoch [7][100/5660]	lr: 1.000e-05, eta: 1:16:37, iter_time: 0.208, data_load_time: 0.016, memory: 7484, loss: 0.3613
# 2023-05-17 22:43:41,809 - modelscope - INFO - epoch [7][200/5660]	lr: 1.000e-05, eta: 1:16:16, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3669
# 2023-05-17 22:44:02,449 - modelscope - INFO - epoch [7][300/5660]	lr: 1.000e-05, eta: 1:15:56, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3521
# 2023-05-17 22:44:23,075 - modelscope - INFO - epoch [7][400/5660]	lr: 1.000e-05, eta: 1:15:36, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3783
# 2023-05-17 22:44:43,692 - modelscope - INFO - epoch [7][500/5660]	lr: 1.000e-05, eta: 1:15:16, iter_time: 0.206, data_load_time: 0.014, memory: 7484, loss: 0.3722

# %% [markdown]
# # test

# %%
# test.py
trainer = build_trainer(name='nlp-base-trainer',default_args=kwargs)
eval_results = trainer.evaluate(f'{WORK_DIR}/epoch_6.pth')

print(eval_results)
# Out:
# 2023-05-21 15:05:25,541 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-21 15:05:26,309 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-21 15:05:27,228 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-21 15:05:27,448 - modelscope - INFO - initialize model from /mnt/workspace/.cache/modelscope/damo/nlp_structbert_sentence-similarity_chinese-base
# 2023-05-21 15:05:33,281 - modelscope - INFO - The key of sentence1: sentence1, The key of sentence2: sentence2, The key of label: label
# 2023-05-21 15:05:33,292 - modelscope - INFO - The key of sentence1: sentence1, The key of sentence2: sentence2, The key of label: label
# 2023-05-21 15:05:33,301 - modelscope - WARNING - ('CUSTOM_DATASETS', 'sentence-similarity', 'structbert') not found in ast index file
# 2023-05-21 15:05:33,302 - modelscope - WARNING - ('CUSTOM_DATASETS', 'sentence-similarity', 'structbert') not found in ast index file
# ** build_dataset error log: 'structbert is not in the custom_datasets registry group sentence-similarity. Please make sure the correct version of ModelScope library is used.'
# ** build_dataset error log: 'structbert is not in the custom_datasets registry group sentence-similarity. Please make sure the correct version of ModelScope library is used.'
# 2023-05-21 15:05:36,945 - modelscope - INFO - ==========================Training Config Start==========================
# 2023-05-21 15:05:36,947 - modelscope - INFO - {
#     "framework": "pytorch",
#     "task": "sentence-similarity",
#     "preprocessor": {
#         "train": {
#             "type": "sen-sim-tokenizer",
#             "first_sequence": "sentence1",
#             "second_sequence": "sentence2",
#             "mode": "train",
#             "use_fast": true
#         },
#         "val": {
#             "type": "sen-sim-tokenizer",
#             "first_sequence": "sentence1",
#             "second_sequence": "sentence2",
#             "mode": "eval",
#             "use_fast": true
#         }
#     },
#     "model": {
#         "type": "structbert"
#     },
#     "pipeline": {
#         "type": "sentence-similarity"
#     },
#     "train": {
#         "work_dir": "./workspace",
#         "max_epochs": 10,
#         "dataloader": {
#             "batch_size_per_gpu": 16,
#             "workers_per_gpu": 1
#         },
#         "optimizer": {
#             "type": "SGD",
#             "lr": 0.01,
#             "options": {
#                 "grad_clip": {
#                     "max_norm": 2.0
#                 }
#             }
#         },
#         "lr_scheduler": {
#             "type": "StepLR",
#             "step_size": 2,
#             "options": {
#                 "warmup": {
#                     "type": "LinearWarmup",
#                     "warmup_iters": 2
#                 }
#             }
#         },
#         "hooks": [
#             {
#                 "type": "IterTimerHook"
#             }
#         ],
#         "logging": {
#             "interval": 100
#         },
#         "checkpoint": {
#             "period": {
#                 "interval": 1
#             }
#         }
#     },
#     "evaluation": {
#         "dataloader": {
#             "batch_size_per_gpu": 16,
#             "workers_per_gpu": 1,
#             "shuffle": false
#         }
#     }
# }
# 2023-05-21 15:05:36,947 - modelscope - INFO - ===========================Training Config End===========================
# 2023-05-21 15:05:36,948 - modelscope - INFO - Stage: before_run:
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_train_iter:
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_train_epoch:
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_val_epoch:
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_run:
#     (LOW         ) CheckpointHook
#  --------------------
#  --- Hook strategies info ---
#
#  --- Hook strategies info end ---
#
# 2023-05-21 15:05:38,158 - modelscope - WARNING - The state_dict of hook <class 'modelscope.trainers.hooks.checkpoint_hook.CheckpointHook'> at index 0 is not found in the checkpoint file.
# 2023-05-21 15:05:38,159 - modelscope - WARNING - The state_dict of hook <class 'modelscope.trainers.hooks.iter_timer_hook.IterTimerHook'> at index 1 is not found in the checkpoint file.
# 2023-05-21 15:05:38,159 - modelscope - WARNING - The state_dict of hook <class 'modelscope.trainers.hooks.logger.text_logger_hook.TextLoggerHook'> at index 2 is not found in the checkpoint file.
# 2023-05-21 15:05:38,160 - modelscope - INFO - Checkpoint ./workspace/epoch_6.pth saving time: Wed May 17 22:42:58 2023, modelscope version: 1.5.0
# Total test samples:   0%|          | 0/60379 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/transformers/modeling_utils.py:831: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   "The `device` argument is deprecated and will be removed in v5 of Transformers.", FutureWarning
# Total test samples: 100%|██████████| 60379/60379 [05:52<00:00, 171.23it/s]
# {'accuracy': 0.8385862634359629, 'binary-f1': 0.9009230644111906, 'f1': 0.9009230644111906}

# %% [markdown]
# # predict

# %%
# predict.py
import os.path as osp
from modelscope.trainers import build_trainer
from modelscope.msdatasets import MsDataset
from modelscope.utils.hub import read_config


model_id = 'damo/nlp_structbert_sentence-similarity_chinese-base'

WORK_DIR = './workspace'

cfg = read_config(model_id)
cfg.train.max_epochs = 10
cfg.train.work_dir = WORK_DIR
cfg.train.hooks = cfg.train.hooks = [{
        'type': 'TextLoggerHook',
        'interval': 100
    }]
cfg_file = osp.join(WORK_DIR, 'train_config.json')
cfg.dump(cfg_file)

local_data = MsDataset.load('csv', data_files={'train': ['./train.csv'], 'test': ['./test.csv']}) 

train_dataset = local_data['train'].to_hf_dataset()
eval_dataset = local_data['test'].to_hf_dataset()

# map float to index
def map_labels(examples):
    map_dict = {0: "不相似", 1: "相似"}
    examples['label'] = map_dict[int(examples['label'])]
    return examples

train_dataset = train_dataset.map(map_labels)
eval_dataset = eval_dataset.map(map_labels)

kwargs = dict(
    model=model_id,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    cfg_file=cfg_file)
# Out:
# 2023-05-21 15:05:03,405 - modelscope - INFO - PyTorch version 1.11.0+cu113 Found.
# 2023-05-21 15:05:03,412 - modelscope - INFO - Loading ast index from /mnt/workspace/.cache/modelscope/ast_indexer
# 2023-05-21 15:05:03,477 - modelscope - INFO - Loading done! Current index file version is 1.5.0, with md5 ca25ccc146d421f40d58ac06319b4460 and a total number of 860 components indexed
# 2023-05-21 15:05:04,490 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# Using custom data configuration default-de0d0344efc1eb27
# Downloading and preparing dataset csv/default to /root/.cache/modelscope/hub/datasets/csv/default-de0d0344efc1eb27/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/modelscope/hub/datasets/csv/default-de0d0344efc1eb27/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/90560 [00:00<?, ?ex/s]
#   0%|          | 0/60379 [00:00<?, ?ex/s]

# %%
# predict
import os
if not os.path.exists('./workspace/tmp/'):
    os.mkdir('./workspace/tmp/')
    
trainer = build_trainer(name='nlp-base-trainer',default_args=kwargs)
pred_data = MsDataset.load('csv', data_files='dev_pred01.csv') 

class SavingFn:
    def __init__(self, inputs, outputs):
        self.filename = './workspace/tmp/results01.txt'
        self.__call__(inputs, outputs)
    def __call__(self, inputs, outputs):
        import numpy as np
        weights = outputs['logits'].cpu().numpy()
        predictions = np.argmax(outputs['logits'].cpu().numpy(), axis=1)
        with open(self.filename, 'a') as f:
            for weight, pred in zip(weights, predictions):
                f.writelines(f'{weight[0]}, {weight[1]}, {pred}\n')

trainer.predict(predict_datasets = pred_data, checkpoint_path='./workspace/epoch_6.pth', saving_fn=SavingFn)
# Out:
# 2023-05-19 01:42:24,574 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-19 01:42:25,156 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-19 01:42:26,031 - modelscope - INFO - Model revision not specified, use the latest revision: v1.0.1
# 2023-05-19 01:42:26,239 - modelscope - INFO - initialize model from /mnt/workspace/.cache/modelscope/damo/nlp_structbert_sentence-similarity_chinese-base
# 2023-05-19 01:42:32,237 - modelscope - INFO - The key of sentence1: sentence1, The key of sentence2: sentence2, The key of label: label
# 2023-05-19 01:42:32,243 - modelscope - INFO - The key of sentence1: sentence1, The key of sentence2: sentence2, The key of label: label
# 2023-05-19 01:42:32,249 - modelscope - WARNING - ('CUSTOM_DATASETS', 'sentence-similarity', 'structbert') not found in ast index file
# 2023-05-19 01:42:32,250 - modelscope - WARNING - ('CUSTOM_DATASETS', 'sentence-similarity', 'structbert') not found in ast index file
# ** build_dataset error log: 'structbert is not in the custom_datasets registry group sentence-similarity. Please make sure the correct version of ModelScope library is used.'
# ** build_dataset error log: 'structbert is not in the custom_datasets registry group sentence-similarity. Please make sure the correct version of ModelScope library is used.'
# 2023-05-19 01:42:36,092 - modelscope - INFO - ==========================Training Config Start==========================
# 2023-05-19 01:42:36,093 - modelscope - INFO - {
#     "framework": "pytorch",
#     "task": "sentence-similarity",
#     "preprocessor": {
#         "train": {
#             "type": "sen-sim-tokenizer",
#             "first_sequence": "sentence1",
#             "second_sequence": "sentence2",
#             "mode": "train",
#             "use_fast": true
#         },
#         "val": {
#             "type": "sen-sim-tokenizer",
#             "first_sequence": "sentence1",
#             "second_sequence": "sentence2",
#             "mode": "eval",
#             "use_fast": true
#         }
#     },
#     "model": {
#         "type": "structbert"
#     },
#     "pipeline": {
#         "type": "sentence-similarity"
#     },
#     "train": {
#         "work_dir": "./workspace",
#         "max_epochs": 10,
#         "dataloader": {
#             "batch_size_per_gpu": 16,
#             "workers_per_gpu": 1
#         },
#         "optimizer": {
#             "type": "SGD",
#             "lr": 0.01,
#             "options": {
#                 "grad_clip": {
#                     "max_norm": 2.0
#                 }
#             }
#         },
#         "lr_scheduler": {
#             "type": "StepLR",
#             "step_size": 2,
#             "options": {
#                 "warmup": {
#                     "type": "LinearWarmup",
#                     "warmup_iters": 2
#                 }
#             }
#         },
#         "hooks": [
#             {
#                 "type": "IterTimerHook"
#             }
#         ],
#         "logging": {
#             "interval": 100
#         },
#         "checkpoint": {
#             "period": {
#                 "interval": 1
#             }
#         }
#     },
#     "evaluation": {
#         "dataloader": {
#             "batch_size_per_gpu": 16,
#             "workers_per_gpu": 1,
#             "shuffle": false
#         }
#     }
# }
# 2023-05-19 01:42:36,094 - modelscope - INFO - ===========================Training Config End===========================
# Using custom data configuration default-4c5039aca13d854c
# Downloading and preparing dataset csv/default to /root/.cache/modelscope/hub/datasets/csv/default-4c5039aca13d854c/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/modelscope/hub/datasets/csv/default-4c5039aca13d854c/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# 2023-05-19 01:42:37,932 - modelscope - INFO - Stage: before_run:
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_train_iter:
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_train_epoch:
#     (LOW         ) CheckpointHook
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_val_epoch:
#     (VERY_LOW    ) TextLoggerHook
#  --------------------
# Stage: after_run:
#     (LOW         ) CheckpointHook
#  --------------------
#  --- Hook strategies info ---
#
#  --- Hook strategies info end ---
#
# 2023-05-19 01:42:39,613 - modelscope - WARNING - The state_dict of hook <class 'modelscope.trainers.hooks.checkpoint_hook.CheckpointHook'> at index 0 is not found in the checkpoint file.
# 2023-05-19 01:42:39,614 - modelscope - WARNING - The state_dict of hook <class 'modelscope.trainers.hooks.iter_timer_hook.IterTimerHook'> at index 1 is not found in the checkpoint file.
# 2023-05-19 01:42:39,614 - modelscope - WARNING - The state_dict of hook <class 'modelscope.trainers.hooks.logger.text_logger_hook.TextLoggerHook'> at index 2 is not found in the checkpoint file.
# 2023-05-19 01:42:39,615 - modelscope - INFO - Checkpoint ./workspace/epoch_6.pth saving time: Wed May 17 22:42:58 2023, modelscope version: 1.5.0
# Total test samples:   0%|          | 0/21089 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/transformers/modeling_utils.py:831: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   "The `device` argument is deprecated and will be removed in v5 of Transformers.", FutureWarning
# Total test samples:   0%|          | 1/21089 [00:00<1:07:06,  5.24it/s]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Total test samples: 100%|██████████| 21089/21089 [01:54<00:00, 183.69it/s]
